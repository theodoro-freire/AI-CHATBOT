# %%
# !pip install pandas matplotlib seaborn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("dados_flu.csv")

df.sample(5)
# Out:
#        id_do_respondente  preocupação_com_h1n1  conhecimento_sobre_h1n1  \
# 1056                1056                   3.0                      2.0
# 18210              18210                   2.0                      2.0
# 5905                5905                   1.0                      2.0
# 8571                8571                   2.0                      1.0
# 18058              18058                   2.0                      2.0
#
#        comportamento_medicamentos_antivirais  comportamento_evitamento  \
# 1056                                     0.0                       1.0
# 18210                                    1.0                       1.0
# 5905                                     0.0                       1.0
# 8571                                     0.0                       1.0
# 18058                                    0.0                       1.0
#
#        comportamento_uso_de_máscara_facial  comportamento_lavagem_das_mãos  \
# ...

# %%
df.info(
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26707 entries, 0 to 26706
# Data columns (total 29 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   id_do_respondente                              26707 non-null  int64
#  1   preocupação_com_h1n1                           26615 non-null  float64
#  2   conhecimento_sobre_h1n1                        26591 non-null  float64
#  3   comportamento_medicamentos_antivirais          26636 non-null  float64
#  4   comportamento_evitamento                       26499 non-null  float64
#  5   comportamento_uso_de_máscara_facial            26688 non-null  float64
#  6   comportamento_lavagem_das_mãos                 26665 non-null  float64
#  7   comportamento_reuniões_grandes                 26620 non-null  float64
#  8   comportamento_saída_de_casa                    26625 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# id_do_respondente                                    0
# preocupação_com_h1n1                                92
# conhecimento_sobre_h1n1                            116
# comportamento_medicamentos_antivirais               71
# comportamento_evitamento                           208
# comportamento_uso_de_máscara_facial                 19
# comportamento_lavagem_das_mãos                      42
# comportamento_reuniões_grandes                      87
# comportamento_saída_de_casa                         82
# comportamento_toque_na_face                        128
# recomendação_médica_h1n1                          2160
# recomendação_médica_sazonal                       2160
# condição_médica_crônica                            971
# criança_menor_de_6_meses                           820
# trabalhador_de_saúde                               804
# seguro_de_saúde                                  12274
# opinião_sobre_a_efetividade_da_vacina_h1n1         391
# ...

# %%
df = df.drop(["seguro_de_saúde","seguro_de_saúde.1","indústria_de_emprego","ocupação"], axis=1)

# %%
plt.figure(figsize=(19,19))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", center=0)
# Out:
# <Axes: >

# %%
x = df[["recomendação_médica_sazonal","opinião_sobre_o_risco_h1n1", "comportamento_uso_de_máscara_facial"]]

y = df["vacina_sazonal"]

# %%
# !pip install scikit-learn

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
clf = DecisionTreeClassifier()

# %%
clf.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
plt.figure(figsize=(20,10))
plot_tree(clf, fontsize=12)
